# %% [markdown]
# ### Checking Political Position Predictions to see if they make sense

# %%
import pandas as pd
import numpy as np
import json

df = pd.read_csv("claude_37_sonnet.tsv", delimiter="\t")

# %%
df.head()
# Out:
#    nodeID   array_of_pol_pos   mean    var    std    NA_count    prob_of_NA
# 0        0                []    nan    nan    nan            5           1.0
# 1        1                []    nan    nan    nan            5           1.0
# 2        2                []    nan    nan    nan            5           1.0
# 3        3                []    nan    nan    nan            5           1.0
# 4        4                []    nan    nan    nan            5           1.0

# %%
print(df.columns)
# Out:
# Index(['nodeID ', ' array_of_pol_pos ', ' mean ', ' var ', ' std ',
#        ' NA_count ', ' prob_of_NA '],
#       dtype='object')

# %%
pol_pos = list(zip(df[" mean "], df[" mean "].index))

# %%
pol_pos = [(float(x[0]), x[1]) for x in pol_pos if "nan" not in x[0]]
pol_pos
# Out:
# [(40.0, 10),
#  (40.0, 11),
#  (50.0, 16),
#  (40.0, 21),
#  (45.0, 28),
#  (60.0, 29),
#  (70.0, 30),
#  (48.0, 31),
#  (45.0, 32),
#  (69.0, 65),
#  (60.0, 94),
#  (40.0, 121),
#  (50.0, 123),
#  (50.0, 124),
#  (50.0, 140),
#  (50.0, 142),
#  (60.0, 147),
#  (50.0, 197),
#  (40.0, 198),
#  (50.0, 200),
#  (70.0, 205),
#  (40.0, 217),
#  (50.0, 219),
#  (50.0, 252),
#  (60.0, 264),
#  (40.0, 269),
#  (30.0, 272),
#  (50.0, 308),
#  (50.0, 325),
#  (60.0, 339),
#  (40.0, 341),
#  (60.0, 356),
#  (40.0, 358),
#  (50.0, 360),
#  (60.0, 361),
#  (50.0, 362),
#  (46.0, 379),
#  (50.0, 395),
#  (40.0, 409),
#  (50.0, 418),
#  (50.0, 419),
#  (40.0, 432),
#  (50.0, 452),
#  (40.0, 489),
#  (50.0, 502),
#  (50.0, 520),
#  (30.0, 542),
#  (30.0, 543),
#  (40.0, 547),
#  (50.0, 598),
#  (50.0, 617),
#  (50.0, 657),
#  (50.0, 658),
#  (52.0, 659),
#  (40.0, 678),
#  (40.0, 690),
#  (40.0, 698),
#  (50.0, 713),
#  (50.0, 718),
#  (40.0, 734),
#  (40.0, 760),
#  (50.0, 765),
#  (50.0, 787),
# ...

# %%
one_dim_pol_pos = [x[1] for x in pol_pos]

# %%
choice_indices = np.random.choice(one_dim_pol_pos, 10,replace=False)
choice_indices = choice_indices.tolist()

# %%
choice_indices
# Out:
# [5380, 8834, 16519, 3207, 23123, 17977, 6029, 22708, 19011, 7298]

# %%
choices = []

with open("../../interim/PoliticalPositions/prompts/prompts.jsonl", "r") as file:
    for line in file:
        datapoint = json.loads(line)
        if int(datapoint.get("id")) in choice_indices:
            choices.append(datapoint)

# %%
claude37sonnet_pol_pos_predictions = [float(x[0]) for x in pol_pos if x[1] in choice_indices]

# %%
models = ["claude_35_haiku.tsv","claude_37_sonnet.tsv", "deepseek_v3.tsv", "gpt35_turbo.tsv", "gpt4o.tsv", "gpt4o_turbo.tsv", "gpt4o_mini.tsv", "o3_mini.tsv", "grok2.tsv", "llama31_8b.tsv", "llama32_3b.tsv", "mistral_7b.tsv"]

# %%
df = pd.read_csv("claude_35_haiku.tsv", delimiter="\t")
pol_pos = list(zip(df[" mean "], df[" mean "].index))
#pol_pos = [(float(x[0]), x[1]) for x in pol_pos if "nan" not in x[0]]
claude35haiku_pol_pos_predictions = [float(x[0]) for x in pol_pos if x[1] in choice_indices]

# %%
df = pd.read_csv("deepseek_v3.tsv", delimiter="\t")
pol_pos = list(zip(df[" mean "], df[" mean "].index))
#pol_pos = [(float(x[0]), x[1]) for x in pol_pos if "nan" not in x[0]]
deepseekv3_pol_pos_predictions = [float(x[0]) for x in pol_pos if x[1] in choice_indices]

# %%
df = pd.read_csv("gpt35_turbo.tsv", delimiter="\t")
pol_pos = list(zip(df[" mean "], df[" mean "].index))
#pol_pos = [(float(x[0]), x[1]) for x in pol_pos if "nan" not in x[0]]
gpt35_turbo_pol_pos_predictions = [float(x[0]) for x in pol_pos if x[1] in choice_indices]

# %%
df = pd.read_csv("gpt4o.tsv", delimiter="\t")
pol_pos = list(zip(df[" mean "], df[" mean "].index))
#pol_pos = [(float(x[0]), x[1]) for x in pol_pos if "nan" not in x[0]]
gpt4o_pol_pos_predictions = [float(x[0]) for x in pol_pos if x[1] in choice_indices]

# %%
df = pd.read_csv("gpt4o_turbo.tsv", delimiter="\t")
pol_pos = list(zip(df[" mean "], df[" mean "].index))
#pol_pos = [(float(x[0]), x[1]) for x in pol_pos if "nan" not in x[0]]
gpt4o_turbo_pol_pos_predictions = [float(x[0]) for x in pol_pos if x[1] in choice_indices]

# %%
df = pd.read_csv("gpt4o_mini.tsv", delimiter="\t")
pol_pos = list(zip(df[" mean "], df[" mean "].index))
#pol_pos = [(float(x[0]), x[1]) for x in pol_pos if "nan" not in x[0]]
gpt4o_mini_pol_pos_predictions = [float(x[0]) for x in pol_pos if x[1] in choice_indices]

# %%
df = pd.read_csv("o3_mini.tsv", delimiter="\t")
pol_pos = list(zip(df[" mean "], df[" mean "].index))
#pol_pos = [(float(x[0]), x[1]) for x in pol_pos if "nan" not in x[0]]
o3_mini_pol_pos_predictions = [float(x[0]) for x in pol_pos if x[1] in choice_indices]

# %%
df = pd.read_csv("grok2.tsv", delimiter="\t")
pol_pos = list(zip(df[" mean "], df[" mean "].index))
#pol_pos = [(float(x[0]), x[1]) for x in pol_pos if "nan" not in x[0]]
grok2_pol_pos_predictions = [float(x[0]) for x in pol_pos if x[1] in choice_indices]

# %%
df = pd.read_csv("llama31_8b.tsv", delimiter="\t")
pol_pos = list(zip(df[" mean "], df[" mean "].index))
#pol_pos = [(float(x[0]), x[1]) for x in pol_pos if "nan" not in x[0]]
llama31_8b_pol_pos_predictions = [float(x[0]) for x in pol_pos if x[1] in choice_indices]

# %%
df = pd.read_csv("llama32_3b.tsv", delimiter="\t")
pol_pos = list(zip(df[" mean "], df[" mean "].index))
#pol_pos = [(float(x[0]), x[1]) for x in pol_pos if "nan" not in x[0]]
llama32_3b_pol_pos_predictions = [float(x[0]) for x in pol_pos if x[1] in choice_indices]

# %%
df = pd.read_csv("mistral_7b.tsv", delimiter="\t")
pol_pos = list(zip(df[" mean "], df[" mean "].index))
#pol_pos = [(float(x[0]), x[1]) for x in pol_pos if "nan" not in x[0]]
mistral_7b_pol_pos_predictions = [float(x[0]) for x in pol_pos if x[1] in choice_indices]

# %%
for choice, cluade37sonnet, claude35haiku, deepseekv3, gpt35_turbo, gpt4o, gpt4o_turbo, gpt4o_mini, o3_mini, grok2,llama31_8b, llama32_3b, mistral_7b in zip(choices, claude37sonnet_pol_pos_predictions, claude35haiku_pol_pos_predictions, 
                                                                                                                                                            deepseekv3_pol_pos_predictions, gpt35_turbo_pol_pos_predictions, gpt4o_pol_pos_predictions,
                                                                                                                                                            gpt4o_turbo_pol_pos_predictions, gpt4o_mini_pol_pos_predictions, o3_mini_pol_pos_predictions,
                                                                                                                                                            grok2_pol_pos_predictions, llama31_8b_pol_pos_predictions, llama32_3b_pol_pos_predictions,
                                                                                                                                                            mistral_7b_pol_pos_predictions):
    prompts = choice["messages"][1]["content"].split("\n")
    print(prompts[2].strip())
    print(prompts[4].strip())
    print("Claude 3.5 Haiku: "+ str(claude35haiku))
    print("Claude 3.7 Sonnet: "+ str(cluade37sonnet))
    print("DeepSeek V3: "+ str(deepseekv3))
    print("GPT 3.5 Turbo: "+ str(gpt35_turbo))
    print("GPT 4o: "+ str(gpt4o))
    print("GPT 4o Turbo: "+ str(gpt4o_turbo))
    print("GPT 4o Mini: "+ str(gpt4o_mini))
    print("o3 Mini: "+ str(o3_mini))
    print("Grok 2: "+ str(grok2))
    print("Llama 3.1:8b: "+ str(llama31_8b))
    print("Llama 3.2:3b: "+ str(llama32_3b))
    print("Mistral:7b: "+ str(mistral_7b))
    print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!\n\n")
# Out:
# Proposition: 'look at that story of the 20th Century, it's a lot of people at the beginning of that century, certainly the disabled, anyone with occasional needs, black and brown people, women, working people, all oppressed in some ways, put down'
# Locution: 'look at that story of the 20th Century, it's a lot of people at the beginning of that century, certainly the disabled, anyone with occasional needs, black and brown people, women, working people, all oppressed in some ways, put down'
# Claude 3.5 Haiku: 10.0
# Claude 3.7 Sonnet: 20.0
# DeepSeek V3: 20.0
# GPT 3.5 Turbo: 10.0
# GPT 4o: 20.0
# GPT 4o Turbo: 11.0
# GPT 4o Mini: 10.0
# o3 Mini: 9.0
# Grok 2: 20.0
# Llama 3.1:8b: 0.0
# Llama 3.2:3b: 0.0
# Mistral:7b: 10.0
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
# Proposition: 'seeing people is how behaviour changes too, people have to see people in positions of power'
# Locution: 'That's how behaviour changes too, by the way -- people have to see people in positions of power'
# ...

# %% [markdown]
# ###  Checking to see if NA scores make sense

# %%
df = pd.read_csv("claude_37_sonnet.tsv", delimiter="\t")

# %%
df.columns
# Out:
# Index(['nodeID ', ' array_of_pol_pos ', ' mean ', ' var ', ' std ',
#        ' NA_count ', ' prob_of_NA '],
#       dtype='object')

# %%
NAs = list(zip(df[" NA_count "], df[" NA_count "].index))
NAs
# Out:
# [(5, 0),
#  (5, 1),
#  (5, 2),
#  (5, 3),
#  (5, 4),
#  (5, 5),
#  (5, 6),
#  (5, 7),
#  (5, 8),
#  (5, 9),
#  (0, 10),
#  (0, 11),
#  (5, 12),
#  (5, 13),
#  (5, 14),
#  (5, 15),
#  (0, 16),
#  (5, 17),
#  (5, 18),
#  (5, 19),
#  (5, 20),
#  (0, 21),
#  (5, 22),
#  (5, 23),
#  (5, 24),
#  (5, 25),
#  (5, 26),
#  (5, 27),
#  (0, 28),
#  (0, 29),
#  (0, 30),
#  (0, 31),
#  (0, 32),
#  (5, 33),
#  (5, 34),
#  (5, 35),
#  (5, 36),
#  (5, 37),
#  (5, 38),
#  (5, 39),
#  (5, 40),
#  (5, 41),
#  (5, 42),
#  (5, 43),
#  (5, 44),
#  (5, 45),
#  (5, 46),
#  (5, 47),
#  (5, 48),
#  (5, 49),
#  (5, 50),
#  (5, 51),
#  (5, 52),
#  (5, 53),
#  (5, 54),
#  (5, 55),
#  (5, 56),
#  (5, 57),
#  (5, 58),
#  (5, 59),
#  (5, 60),
#  (5, 61),
#  (5, 62),
#  (5, 63),
#  (5, 64),
#  (0, 65),
#  (5, 66),
#  (5, 67),
#  (5, 68),
#  (5, 69),
#  (5, 70),
#  (5, 71),
#  (5, 72),
#  (5, 73),
#  (5, 74),
#  (5, 75),
#  (5, 76),
#  (5, 77),
#  (5, 78),
#  (5, 79),
#  (5, 80),
#  (5, 81),
#  (5, 82),
#  (5, 83),
# ...

# %%
NAs = [x for x in NAs if x[0] == 5]

# %%
NAs
# Out:
# [(5, 0),
#  (5, 1),
#  (5, 2),
#  (5, 3),
#  (5, 4),
#  (5, 5),
#  (5, 6),
#  (5, 7),
#  (5, 8),
#  (5, 9),
#  (5, 12),
#  (5, 13),
#  (5, 14),
#  (5, 15),
#  (5, 17),
#  (5, 18),
#  (5, 19),
#  (5, 20),
#  (5, 22),
#  (5, 23),
#  (5, 24),
#  (5, 25),
#  (5, 26),
#  (5, 27),
#  (5, 33),
#  (5, 34),
#  (5, 35),
#  (5, 36),
#  (5, 37),
#  (5, 38),
#  (5, 39),
#  (5, 40),
#  (5, 41),
#  (5, 42),
#  (5, 43),
#  (5, 44),
#  (5, 45),
#  (5, 46),
#  (5, 47),
#  (5, 48),
#  (5, 49),
#  (5, 50),
#  (5, 51),
#  (5, 52),
#  (5, 53),
#  (5, 54),
#  (5, 55),
#  (5, 56),
#  (5, 57),
#  (5, 58),
#  (5, 59),
#  (5, 60),
#  (5, 61),
#  (5, 62),
#  (5, 63),
#  (5, 64),
#  (5, 66),
#  (5, 67),
#  (5, 68),
#  (5, 69),
#  (5, 70),
#  (5, 71),
#  (5, 72),
#  (5, 73),
#  (5, 74),
#  (5, 75),
#  (5, 76),
#  (5, 77),
#  (5, 78),
#  (5, 79),
#  (5, 80),
#  (5, 81),
#  (5, 82),
#  (5, 83),
#  (5, 84),
#  (5, 85),
#  (5, 86),
#  (5, 87),
#  (5, 88),
#  (5, 89),
#  (5, 90),
#  (5, 91),
#  (5, 92),
#  (5, 93),
# ...

# %%
one_dim_NAs = [x[1] for x in NAs]

# %%
choice_indices = np.random.choice(one_dim_NAs, 10,replace=False)
choice_indices = choice_indices.tolist()

# %%
claude37sonnet_NAs_predictions = [float(x[0]) for x in NAs if x[1] in choice_indices]

# %%
choice_indices
# Out:
# [17636, 14505, 2416, 12183, 13694, 14936, 4653, 10951, 12031, 18002]

# %%
choices = []

with open("../../interim/PoliticalPositions/prompts/prompts.jsonl", "r") as file:
    for line in file:
        datapoint = json.loads(line)
        if int(datapoint.get("id")) in choice_indices:
            choices.append(datapoint)

# %%
df = pd.read_csv("claude_35_haiku.tsv", delimiter="\t")
NAs = list(zip(df[" NA_count "], df[" NA_count "].index))
#NAs = [(float(x[0]), x[1]) for x in NAs if "nan" not in x[0]]
claude35haiku_NAs_predictions = [float(x[0]) for x in NAs if x[1] in choice_indices]

# %%
df = pd.read_csv("deepseek_v3.tsv", delimiter="\t")
NAs = list(zip(df[" NA_count "], df[" NA_count "].index))
#NAs = [(float(x[0]), x[1]) for x in NAs if "nan" not in x[0]]
deepseekv3_NAs_predictions = [float(x[0]) for x in NAs if x[1] in choice_indices]

# %%
df = pd.read_csv("gpt35_turbo.tsv", delimiter="\t")
NAs = list(zip(df[" NA_count "], df[" NA_count "].index))
#NAs = [(float(x[0]), x[1]) for x in NAs if "nan" not in x[0]]
gpt35_turbo_NAs_predictions = [float(x[0]) for x in NAs if x[1] in choice_indices]

# %%
df = pd.read_csv("gpt4o.tsv", delimiter="\t")
NAs = list(zip(df[" NA_count "], df[" NA_count "].index))
#NAs = [(float(x[0]), x[1]) for x in NAs if "nan" not in x[0]]
gpt4o_NAs_predictions = [float(x[0]) for x in NAs if x[1] in choice_indices]

# %%
df = pd.read_csv("gpt4o_turbo.tsv", delimiter="\t")
NAs = list(zip(df[" NA_count "], df[" NA_count "].index))
#NAs = [(float(x[0]), x[1]) for x in NAs if "nan" not in x[0]]
gpt4o_turbo_NAs_predictions = [float(x[0]) for x in NAs if x[1] in choice_indices]

# %%
df = pd.read_csv("gpt4o_mini.tsv", delimiter="\t")
NAs = list(zip(df[" NA_count "], df[" NA_count "].index))
#NAs = [(float(x[0]), x[1]) for x in NAs if "nan" not in x[0]]
gpt4o_mini_NAs_predictions = [float(x[0]) for x in NAs if x[1] in choice_indices]

# %%
df = pd.read_csv("o3_mini.tsv", delimiter="\t")
NAs = list(zip(df[" NA_count "], df[" NA_count "].index))
#NAs = [(float(x[0]), x[1]) for x in NAs if "nan" not in x[0]]
o3_mini_NAs_predictions = [float(x[0]) for x in NAs if x[1] in choice_indices]

# %%
df = pd.read_csv("grok2.tsv", delimiter="\t")
NAs = list(zip(df[" NA_count "], df[" NA_count "].index))
#NAs = [(float(x[0]), x[1]) for x in NAs if "nan" not in x[0]]
grok2_NAs_predictions = [float(x[0]) for x in NAs if x[1] in choice_indices]

# %%
df = pd.read_csv("llama31_8b.tsv", delimiter="\t")
NAs = list(zip(df[" NA_count "], df[" NA_count "].index))
#NAs = [(float(x[0]), x[1]) for x in NAs if "nan" not in x[0]]
llama31_8b_NAs_predictions = [float(x[0]) for x in NAs if x[1] in choice_indices]

# %%
df = pd.read_csv("llama32_3b.tsv", delimiter="\t")
NAs = list(zip(df[" NA_count "], df[" NA_count "].index))
#NAs = [(float(x[0]), x[1]) for x in NAs if "nan" not in x[0]]
llama32_3b_NAs_predictions = [float(x[0]) for x in NAs if x[1] in choice_indices]

# %%
df = pd.read_csv("mistral_7b.tsv", delimiter="\t")
NAs = list(zip(df[" NA_count "], df[" NA_count "].index))
#NAs = [(float(x[0]), x[1]) for x in NAs if "nan" not in x[0]]
mistral_7b_NAs_predictions = [float(x[0]) for x in NAs if x[1] in choice_indices]

# %%
for choice, cluade37sonnet, claude35haiku, deepseekv3, gpt35_turbo, gpt4o, gpt4o_turbo, gpt4o_mini, o3_mini, grok2,llama31_8b, llama32_3b, mistral_7b in zip(choices, claude37sonnet_NAs_predictions, claude35haiku_NAs_predictions, 
                                                                                                                                                            deepseekv3_NAs_predictions, gpt35_turbo_NAs_predictions, gpt4o_NAs_predictions,
                                                                                                                                                            gpt4o_turbo_NAs_predictions, gpt4o_mini_NAs_predictions, o3_mini_NAs_predictions,
                                                                                                                                                            grok2_NAs_predictions, llama31_8b_NAs_predictions, llama32_3b_NAs_predictions,
                                                                                                                                                            mistral_7b_NAs_predictions):
    prompts = choice["messages"][1]["content"].split("\n")
    print(prompts[2].strip())
    print(prompts[4].strip())
    print("Claude 3.5 Haiku: "+ str(claude35haiku))
    print("Claude 3.7 Sonnet: "+ str(cluade37sonnet))
    print("DeepSeek V3: "+ str(deepseekv3))
    print("GPT 3.5 Turbo: "+ str(gpt35_turbo))
    print("GPT 4o: "+ str(gpt4o))
    print("GPT 4o Turbo: "+ str(gpt4o_turbo))
    print("GPT 4o Mini: "+ str(gpt4o_mini))
    print("o3 Mini: "+ str(o3_mini))
    print("Grok 2: "+ str(grok2))
    print("Llama 3.1:8b: "+ str(llama31_8b))
    print("Llama 3.2:3b: "+ str(llama32_3b))
    print("Mistral:7b: "+ str(mistral_7b))
    print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!\n\n")
# Out:
# Proposition: 'If Keir Starmer was prime minister he would or would not give the Scottish the right to have a say'
# Locution: 'If Keir Starmer was prime minister would he give them that right'
# Claude 3.5 Haiku: 0.0
# Claude 3.7 Sonnet: 5.0
# DeepSeek V3: 0.0
# GPT 3.5 Turbo: 0.0
# GPT 4o: 5.0
# GPT 4o Turbo: 5.0
# GPT 4o Mini: 0.0
# o3 Mini: 0.0
# Grok 2: 0.0
# Llama 3.1:8b: 0.0
# Llama 3.2:3b: 0.0
# Mistral:7b: 0.0
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
# Proposition: 'xxx is how SNP would pay their share of the debt which is now enormous'
# Locution: 'How would you pay your share of the debt which is now enormous'
# Claude 3.5 Haiku: 0.0
# Claude 3.7 Sonnet: 5.0
# DeepSeek V3: 0.0
# GPT 3.5 Turbo: 0.0
# GPT 4o: 5.0
# GPT 4o Turbo: 5.0
# GPT 4o Mini: 0.0
# o3 Mini: 0.0
# Grok 2: 0.0
# Llama 3.1:8b: 0.0
# Llama 3.2:3b: 0.0
# Mistral:7b: 0.0
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
# Proposition: 'if any, the politicians should have the further protection is xxx'
# ...
